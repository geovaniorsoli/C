# %%
print("hello world \n")
print("olá mundo ")
# Out:
# hello world
#
# olá mundo

# %%
mensagem = 'Quem disse que cachorro velho não aprende truque novo'
print("Mensagem da Redbull:", mensagem)
# Out:
# Mensagem da Redbull: Quem disse que cachorro velho não aprende truque novo

# %%
num1 = 5
num2 = 10
print("Número é:",num1, num2)
# Out:
# Número é: 5 10

# %%
print("Seu nome\n")
nome = input("nome")

print("Senha\n")
senha = input("Senha")

print("Suas credencias são: ")
print (
    f"\n nome => {nome}"
    f"\n senha => {senha}"
)
# Out:
# Seu nome
#
# Senha
#
# Suas credencias são:
#
#  nome => café
#  senha => preto

# %%
def numeroCerto(numero):
    if numero > 5:
        print(" ")
        if numero < 7:
            print (" menos q 7")
            if numero == 3:
                print (" 3")
                if numero < 30:
                    return ("numero é menos q trinta")
    else:
        print("numero")

# %%
print("digite um numero: ")
numero = int(input("digite numero"))

numeroCerto(numero)
# Out:
# digite um numero:
# numero
